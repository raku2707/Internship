# %% [markdown]
# # ASSIGNMENT-2
#
# ## WEB SCRAPING
#
# ### All the questions must be done in a single Jupyter notebook and there should be proper comments incode.
#
# 1. **[Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.](#naukri)**
# 2. **[Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data. This task will be done in following steps.](#data_analyst)**
# 3. **[In this question you have to scrape data using the filters available on the webpage.](#webpage)**
# 4. **[Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes.](#sunglasses)**
# 5. **[Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKART](#flipkart)**
# 6. **[Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.](#sneakers)**
# 7. **[Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7”.](#amazon)**
# 8. **[Write a python program to scrape data for Top 1000 Quotes of All Time.](#python_program)**
# 9. **[Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.](#jagranjosh)**

# %%
#Insall selenium

# !pip install selenium

# %%
#Import some necessary libraries

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# <a id="naukri"> </a>
# ## 1. Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
#Let's first connect to the driver

driver=webdriver.Chrome(r"C:\Users\HP\Internship\chromedriver_win32\chromedriver")

# %%
#Opening the naukri page on automated chrome browser
driver.get('https://www.naukri.com/')

# %%
#Entering designation as required in the question

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Analyst")

# %%
#Entering location as required in the question

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys("Bangalore")

# %%
#Search

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
#Scrapping Job title from naukri page

Job_title=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    Job_title.append(title)

# %%
#Scrapping Job location from naukri page

Job_location=[]

location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)

# %%
#Scrapping company name from naukri page

Company_name=[]

company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    Company_name.append(company)

# %%
#Scrapping experience from naukri page

Work_experience=[]

experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    Work_experience.append(experience)

# %%
#Print length

print(len(Job_title),len(Job_location),len(Company_name),len(Work_experience))
# Out:
# 10 10 10 10

# %%
#Create DataFrame
import pandas as pd
Naukri_com=pd.DataFrame({'Job Title':Job_title,'Job Location':Job_location,'Company_name':Company_name,'Experience required':Work_experience})
Naukri_com
# Out:
#                           Job Title  \
# 0                      Data Analyst
# 1                      Data Analyst
# 2  Data Analyst - IIT/BITS/Startups
# 3            Data Analyst - FinTech
# 4            Data Analyst - FinTech
# 5            Data Analyst - FinTech
# 6  Data Analyst - IIT/BITS/Startups
# 7                      Data Analyst
# 8              Banking Data Analyst
# 9                      Data Analyst
#
#                                         Job Location  Company_name  \
# 0                                Bangalore/Bengaluru           ANZ
# 1                                Bangalore/Bengaluru           ANZ
# 2                                Bangalore/Bengaluru  AVE Promagne
# 3  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...  Primo Hiring
# 4  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...  Primo Hiring
# 5  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...  Primo Hiring
# 6                                Bangalore/Bengaluru  AVE Promagne
# ...

# %% [markdown]
# <a id="data_analyst"> </a>
# ## 2.Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data. This task will be done in following steps.
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results youget.
# 5. Finally create a dataframe of the scraped data.

# %%
#Let's first connect to the driver

driver=webdriver.Chrome(r"C:\Users\HP\Internship\chromedriver_win32\chromedriver")

# %%
#Opening the naukri page on automated chrome browser
driver.get('https://www.naukri.com/')

# %%
#Entering designation as required in the question

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Analyst")

# %%
#Entering location as required in the question

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys("Bangalore")

# %%
#Search

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
#Scrapping Job title from naukri page

Job_title=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    Job_title.append(title)

# %%
#Scrapping Job location from naukri page

Job_location=[]

location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)

# %%
#Scrapping company name from naukri page

Company_name=[]

company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    Company_name.append(company)

# %%
#Print length

print(len(Job_title),len(Job_location),len(Company_name))
# Out:
# 10 10 10

# %%
#Create DataFrame
import pandas as pd
Naukri_com=pd.DataFrame({'Job Title':Job_title,'Job Location':Job_location,'Company_name':Company_name})
Naukri_com
# Out:
#                           Job Title  \
# 0                      Data Analyst
# 1                      Data Analyst
# 2  Data Analyst - IIT/BITS/Startups
# 3            Data Analyst - FinTech
# 4            Data Analyst - FinTech
# 5            Data Analyst - FinTech
# 6  Data Analyst - IIT/BITS/Startups
# 7                      Data Analyst
# 8              Banking Data Analyst
# 9                      Data Analyst
#
#                                         Job Location  Company_name
# 0                                Bangalore/Bengaluru           ANZ
# 1                                Bangalore/Bengaluru           ANZ
# 2                                Bangalore/Bengaluru  AVE Promagne
# 3  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...  Primo Hiring
# 4  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...  Primo Hiring
# 5  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...  Primo Hiring
# 6                                Bangalore/Bengaluru  AVE Promagne
# ...

# %% [markdown]
# <a id="webpage"> </a>
# ## 3.In this question you have to scrape data using the filters available on the webpage as shown below.
#
#     You have to use the location and salary filter.
#     You have to scrape data for “Data Scientist” designation for first 10 job results.
#     You have to scrape the job-title, job-location, company name, experience required.
#     The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
#     The task will be done as shown in the below steps:
# 1. first get thewebpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the searchbutton.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results youget.
# 6. Finally create a dataframe of the scraped data.

# %%
#Let's first connect to the driver

driver=webdriver.Chrome(r"C:\Users\HP\Internship\chromedriver_win32\chromedriver")

# %%
#Opening the naukri page on automated chrome browser
driver.get('https://www.naukri.com/')

# %%
#Entering designation as required in the question

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Analyst")

# %%
#Search

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
#Used location filter (Delhi/NCR)

location_filter=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[4]/div[2]/div[2]/label/p/span[1]")
location_filter.click()

# %%
#Used salary filter (3-6 lakhs)

salary_filter=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]")
salary_filter.click()

# %%
#Scrapping Job title from naukri page

Job_title=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    Job_title.append(title)

# %%
#Scrapping Job location from naukri page

Job_location=[]

location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)

# %%
#Scrapping Salary from naukri page

Salary=[]

salary_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft "]')
for i in salary_tags[0:10]:
    salary=i.text
    Salary.append(salary)

# %%
#Scrapping company name from naukri page

Company_name=[]

company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    Company_name.append(company)

# %%
#Scrapping experience from naukri page

Work_experience=[]

experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    Work_experience.append(experience)

# %%
#Print length

print(len(Job_title),len(Job_location),len(Company_name),len(Work_experience))
# Out:
# 10 10 10 10

# %%
#Create DataFrame
import pandas as pd
Naukri_com=pd.DataFrame({'Job Title':Job_title,'Job Location':Job_location,'Company_name':Company_name,'Experience required':Work_experience})
Naukri_com
# Out:
#       Job Title                                       Job Location  \
# 0  Data Analyst                 Noida, New Delhi, Gurgaon/Gurugram
# 1  Data Analyst                                  Mumbai, New Delhi
# 2  Data Analyst                                              Noida
# 3  Data Analyst  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 4  Data Analyst  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 5  Data Analyst  Delhi / NCR, Kolkata, Indore, Hyderabad/Secund...
# 6  Data Analyst                                        Delhi / NCR
# 7  Data Analyst                                              Noida
# 8  Data Analyst                      Noida, Hyderabad/Secunderabad
# 9  Data Analyst                                     Hybrid - Noida
#
#                   Company_name Experience required
# 0                      Premium             0-2 Yrs
# 1  Structural Solutions (SSPL)             2-7 Yrs
# 2         Addverb Technologies             1-3 Yrs
# ...

# %% [markdown]
# <a id="sunglasses"> </a>
# ## 4. Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. ProductDescription
# 3. Price
#
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url :https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data asusual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then click on it.
# 5. Now scrape data from this page asusual
# 6. Repeat this until you get data for 100sunglasses.

# %%
#Let's first connect to the driver

driver=webdriver.Chrome(r"C:\Users\HP\Internship\chromedriver_win32\chromedriver")

# %%
#Opening the flipkart page on automated chrome browser

driver.get('https://www.flipkart.com/')

# %%
#logging into flipkart and providing necessary information
email_btn=driver.find_element(By.XPATH,"//input[@class='_2IX_2- VJZDxU']")
email_btn.send_keys('9173729386')

# %%
#OTP

otp_btn=driver.find_element(By.CLASS_NAME,"_1k3JO2")
otp_btn.click()

# %%
#Enter Otp ()

Enter_otp_btn=driver.find_element(By.XPATH,'//input[@class="_2IX_2- _1WRfas"]')
Enter_otp_btn.send_keys('175647')

# %%
#Entering product as required in the question

search_items=driver.find_element(By.CLASS_NAME,'_3704LK')
search_items.send_keys("sunglasses")

# %%
#Search

search=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
#Scrapping sunglasses brand name from flipkart page

brand_name=[]

brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:10]:
    brand=i.text
    brand_name.append(brand)

# %%
#Scrap three page data

start=0
end=3
for page in range (start,end):
    brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags:
        brand_name.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
#Fetch top 100 data from product brand

brand_name[0:100]
# Out:
# ['VINCENT CHASE',
#  'VINCENT CHASE',
#  'PIRASO',
#  'PIRASO',
#  'TamTam',
#  'PIRASO',
#  'Fastrack',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Shaah Collection',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'PIRASO',
#  'PIRASO',
#  'TamTam',
#  'PIRASO',
#  'Fastrack',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Shaah Collection',
#  'SUNBEE',
#  'VINCENT CHASE',
#  'Fastrack',
#  'NuVew',
#  'PIRASO',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Fastrack',
#  'PIRASO',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Fastrack',
#  'METRONAUT',
#  'VINCENT CHASE',
#  'NuVew',
#  'Fastrack',
#  'Fastrack',
#  'VINCENT CHASE',
#  'Fastrack',
#  'NuVew',
#  'PIRASO',
#  'VINCENT CHASE',
#  'NuVew',
#  'Fastrack',
#  'Fastrack',
#  'VINCENT CHASE',
#  'PIRASO',
#  'Silver Kartz',
#  'Fastrack',
#  'VINCENT CHASE',
#  'Fastrack',
#  'PIRASO',
#  'GANSTA',
#  'VINCENT CHASE',
#  'Fastrack',
#  'MGKNYAH',
#  'SUNBEE',
#  'VINCENT CHASE',
#  'Fastrack',
#  'PIRASO',
#  'SUNBEE',
#  'VINCENT CHASE',
#  'NuVew',
# ...

# %%
#Scrap 1st page

previous=driver.find_element(By.XPATH,"/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[1]")
previous.click()

# %%
#Scrapping product desription from flipkart page

product_description=[]

description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:10]:
    description=i.text
    product_description.append(description)

# %%
#Scrap three page data

start=0
end=3
for page in range (start,end):
    description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description_tags:
        product_description.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
#Fetch top 100 data from product description

product_description[0:100]
# Out:
# ['by Lenskart Polarized, UV Protection Retro Square Sungl...',
#  'by Lenskart Polarized, UV Protection Retro Square Sungl...',
#  'UV Protection Clubmaster Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'Polarized, Night Vision, Riding Glasses Sports, Wrap-ar...',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'by Lenskart Polarized, UV Protection Retro Square Sungl...',
#  'by Lenskart Polarized, UV Protection Retro Square Sungl...',
#  'UV Protection Clubmaster Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
# ...

# %%
#Scrap 1st page

previous=driver.find_element(By.XPATH,"/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[1]")
previous.click()

# %%
#Scrapping sunglasses price from flipkart page

price_list=[]

price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:10]:
    price=i.text
    price_list.append(price)

# %%
#Scrap three page data

start=0
end=3
for page in range (start,end):
    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        price_list.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
#Fetch top 100 data from product price

price_list[0:100]
# Out:
# ['₹849',
#  '₹849',
#  '₹224',
#  '₹268',
#  '₹181',
#  '₹274',
#  '₹509',
#  '₹699',
#  '₹559',
#  '₹185',
#  '₹849',
#  '₹849',
#  '₹224',
#  '₹268',
#  '₹181',
#  '₹274',
#  '₹509',
#  '₹699',
#  '₹559',
#  '₹185',
#  '₹293',
#  '₹499',
#  '₹539',
#  '₹129',
#  '₹211',
#  '₹695',
#  '₹489',
#  '₹539',
#  '₹174',
#  '₹899',
#  '₹599',
#  '₹549',
#  '₹244',
#  '₹249',
#  '₹99',
#  '₹729',
#  '₹509',
#  '₹199',
#  '₹891',
#  '₹125',
#  '₹214',
#  '₹243',
#  '₹115',
#  '₹549',
#  '₹509',
#  '₹699',
#  '₹529',
#  '₹239',
#  '₹267',
#  '₹244',
#  '₹479',
#  '₹212',
#  '₹292',
#  '₹509',
#  '₹1,049',
#  '₹189',
#  '₹259',
#  '₹789',
#  '₹489',
#  '₹214',
#  '₹185',
#  '₹789',
#  '₹99',
#  '₹125',
#  '₹179',
#  '₹965',
#  '₹125',
#  '₹211',
#  '₹199',
#  '₹789',
#  '₹189',
#  '₹437',
#  '₹373',
#  '₹873',
#  '₹489',
#  '₹489',
#  '₹242',
#  '₹849',
#  '₹292',
#  '₹759',
#  '₹519',
#  '₹879',
#  '₹2,789',
#  '₹316',
#  '₹190',
#  '₹879',
#  '₹199',
#  '₹185',
#  '₹499',
#  '₹769',
# ...

# %%
#Scrap 1st page

previous=driver.find_element(By.XPATH,"/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[1]")
previous.click()

# %%
#Scrapping sunglasses discount from flipkart page

discount_list=[]

dis_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in dis_tags[0:10]:
    discount=i.text
    discount_list.append(discount)

# %%
#Scrap three page data

start=0
end=3
for page in range (start,end):
    dis_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in dis_tags:
        discount_list.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
#Fetch top 100 data from product discount

discount_list[0:100]
# Out:
# ['57% off',
#  '57% off',
#  '85% off',
#  '83% off',
#  '81% off',
#  '89% off',
#  '49% off',
#  '65% off',
#  '49% off',
#  '89% off',
#  '57% off',
#  '57% off',
#  '85% off',
#  '83% off',
#  '81% off',
#  '89% off',
#  '49% off',
#  '65% off',
#  '49% off',
#  '89% off',
#  '77% off',
#  '65% off',
#  '46% off',
#  '86% off',
#  '86% off',
#  '75% off',
#  '45% off',
#  '46% off',
#  '91% off',
#  '81% off',
#  '45% off',
#  '45% off',
#  '81% off',
#  '65% off',
#  '88% off',
#  '47% off',
#  '49% off',
#  '75% off',
#  '18% off',
#  '83% off',
#  '86% off',
#  '65% off',
#  '86% off',
#  '45% off',
#  '74% off',
#  '90% off',
#  '47% off',
#  '85% off',
#  '82% off',
#  '75% off',
#  '46% off',
#  '86% off',
#  '85% off',
#  '74% off',
#  '25% off',
#  '68% off',
#  '80% off',
#  '60% off',
#  '45% off',
#  '86% off',
#  '81% off',
#  '60% off',
#  '88% off',
#  '85% off',
#  '82% off',
#  '51% off',
#  '83% off',
#  '86% off',
#  '60% off',
#  '60% off',
#  '68% off',
# ...

# %%
#Print length

print(len(brand_name),len(product_description),len(discount_list),len(price_list))
# Out:
# 130 127 130 130

# %%
#Create DataFrame

flipkart_Sunglasses=pd.DataFrame()
flipkart_Sunglasses["BRAND"]=brand_name[:100]
flipkart_Sunglasses["PRODUCT_DESCRIPTION"]=product_description[:100]
flipkart_Sunglasses["DISCOUNT"]=discount_list[:100]
flipkart_Sunglasses["PRICE"]=price_list[:100]

flipkart_Sunglasses
# Out:
#                BRAND                                PRODUCT_DESCRIPTION  \
# 0      VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...
# 1      VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...
# 2             PIRASO           UV Protection Clubmaster Sunglasses (54)
# 3             PIRASO       UV Protection Aviator Sunglasses (Free Size)
# 4             TamTam  UV Protection Retro Square Sunglasses (Free Size)
# ..               ...                                                ...
# 95            PIRASO                  Polarized Aviator Sunglasses (56)
# 96          Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 97     VINCENT CHASE  UV Protection, Polarized, Mirrored Rectangular...
# 98          Fastrack  UV Protection, Polarized Wayfarer Sunglasses (...
# 99  Shaah Collection                  Polarized Aviator Sunglasses (56)
#
#    DISCOUNT PRICE
# 0   57% off  ₹849
# 1   57% off  ₹849
# 2   85% off  ₹224
# 3   83% off  ₹268
# ...

# %% [markdown]
# <a id="flipkart"> </a>
# ## 5. Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKART
#
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews.

# %%
#Let's first connect to the driver
          
driver=webdriver.Chrome(r"C:\Users\HP\Internship\chromedriver_win32\chromedriver")

# %%
#Opening the flipkart page on automated chrome browser

driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market')

# %%
#Scrapping iphone 11 rating from flipkart page

Rating=[]

rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:5]:
    rating=i.text
    Rating.append(rating)

# %%
#Scrap multiple page data

start=0
end=11
for page in range (start,end):
    rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tags:
        Rating.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
#Fetch top 100 data from iphone 11 rating

Rating[0:100]
# Out:
# ['5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4']

# %%
#Scrap 1st page

previous=driver.find_element(By.XPATH,"/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[2]")
previous.click()

# %%
#Scrapping iphone 11 Review summary from flipkart page

Review_summary=[]

summary_tags=driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']")
for i in summary_tags[0:10]:
    summary=i.text
    Review_summary.append(summary)

# %%
#Scrap multiple page data

start=0
end=11
for page in range (start,end):
    summary_tags=driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']")
    for i in summary_tags:
        Review_summary.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
#Fetch top 100 data from iphone 11 Review summary

Review_summary[0:100]
# Out:
# ['Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Pretty good',
#  'Perfect product!',
#  'Highly recommended',
#  'Great product',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Pretty good',
#  'Perfect product!',
#  'Highly recommended',
#  'Great product',
#  'Fabulous!',
#  'Classy product',
#  'Worth every penny',
#  'Perfect product!',
#  'Good choice',
#  'Perfect product!',
#  'Highly recommended',
#  'Highly recommended',
#  'Value-for-money',
#  'Perfect product!',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Pretty good',
#  'Perfect product!',
#  'Highly recommended',
#  'Great product',
#  'Fabulous!',
#  'Classy product',
#  'Worth every penny',
#  'Perfect product!',
# ...

# %%
#Scrap 1st page

previous=driver.find_element(By.XPATH,"/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[2]")
previous.click()

# %%
#Scrapping iphone 11 full Review from flipkart page

Full_review=[]

review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in review_tags[0:10]:
    review=i.text
    Full_review.append(review)

# %%
#Scrap multiple page data

start=0
end=11
for page in range (start,end):
    review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in review_tags:
        Full_review.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
#Fetch top 100 data from iphone 11 Full Review

Full_review[0:100]
# Out:
# ['Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.',
#  'Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .',
#  'Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7.\nPros\n-Camera top class\n- Battery top performed\n-Chipset no need to say as apple kind\n-Security as you expect from apple\n- Display super bright industry leading colour\naccuracy and super responsive\n-Build quality as expect from apple sturdy\npremium durable beautiful stylish.\n-Os most stable os in smartphone industry\n\nCons\n-No 5G\n-Display is not based on OLED technology\n-Charger headphones and 1 apple stic...\nREAD MORE',
#  "I'm Really happy with the product\nDelivery was fast as well\n..it was a gift for my sister and she loved it so much.",
# ...

# %%
#Print length

print(len(brand_name),len(product_description),len(discount_list),len(price_list))
# Out:
# 130 127 130 130

# %%
#Create DataFrame

Iphone11_review=pd.DataFrame()
Iphone11_review["RATING"]=Rating[:100]
Iphone11_review["REVIEW SUMMARY"]=Review_summary[:100]
Iphone11_review["FULL REVIEW"]=Full_review[:100]

Iphone11_review
# Out:
#    RATING       REVIEW SUMMARY  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5   Highly recommended
# ..    ...                  ...
# 95      5    Worth every penny
# 96      5          Pretty good
# 97      5     Perfect product!
# 98      5   Highly recommended
# 99      4        Great product
#
#                                           FULL REVIEW
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Previously I was using one plus 3t it was a gr...
# 96  I was using Iphone 6s and also Oneplus 6t. Bot...
# 97  Value for money\n5 star rating\nExcellent came...
# ...

# %% [markdown]
# <a id="sneakers"> </a>
# ## 6. Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. ProductDescription
# 3. Price
#
# As shown in the below image, you have to scrape the above attributes.

# %%
#Let's first connect to the driver

driver=webdriver.Chrome(r"C:\Users\HP\Internship\chromedriver_win32\chromedriver")

# %%
#Opening the flipkart page on automated chrome browser

driver.get('https://www.flipkart.com/')

# %%
#logging into flipkart and providing necessary information
email_btn=driver.find_element(By.XPATH,"//input[@class='_2IX_2- VJZDxU']")
email_btn.send_keys('9173729386')

# %%
#OTP

otp_btn=driver.find_element(By.CLASS_NAME,"_1k3JO2")
otp_btn.click()

# %%
#Enter Otp ()

Enter_otp_btn=driver.find_element(By.XPATH,'//input[@class="_2IX_2- _1WRfas"]')
Enter_otp_btn.send_keys('912817')

# %%
#Entering product as required in the question

search_items=driver.find_element(By.CLASS_NAME,'_3704LK')
search_items.send_keys("Sneakers")

# %%
#Search

search=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
#Scrapping sneakers brand name from flipkart page

brand_name=[]

brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:10]:
    brand=i.text
    brand_name.append(brand)

# %%
start=0
end=3
for page in range (start,end):
    brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags:
        brand_name.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
len(brand_name)
# Out:
# 130

# %%
brand_name[0:100]
# Out:
# ['Kraasa',
#  'BIRDE',
#  'BIRDE',
#  'BIRDE',
#  'Kraasa',
#  'BIRDE',
#  'aadi',
#  'Shozie',
#  'asian',
#  'BRUTON',
#  'Kraasa',
#  'BIRDE',
#  'BIRDE',
#  'BIRDE',
#  'Kraasa',
#  'BIRDE',
#  'aadi',
#  'Shozie',
#  'asian',
#  'BRUTON',
#  'Layasa',
#  'Magnolia',
#  'BRUTON',
#  'Labbin',
#  'BIRDE',
#  'aadi',
#  'BRUTON',
#  'asian',
#  'World Wear Footwear',
#  'HRX by Hrithik Roshan',
#  'HIGHLANDER',
#  'Shozie',
#  'aadi',
#  'BIRDE',
#  'RINDAS',
#  'RED TAPE',
#  'Magnolia',
#  'Layasa',
#  'BIRDE',
#  'BIRDE',
#  'World Wear Footwear',
#  'BERSACHE',
#  'Shozie',
#  'HIGHLANDER',
#  'aadi',
#  'Deals4you',
#  'aadi',
#  'BRUTON',
#  'asian',
#  'aadi',
#  'Skechers',
#  'lejano',
#  'aadi',
#  'BERSACHE',
#  'Shozie',
#  'BRUTON',
#  'Layasa',
#  'asian',
#  'BIRDE',
#  'Deals4you',
#  'PUMA',
#  'PUMA',
#  'BRUTON',
#  'asian',
#  'asian',
#  'PUMA',
#  'kardam&sons',
#  'Kraasa',
#  'WHITE WALKERS',
#  'BIRDE',
#  'BIRDE',
#  'BIRDE',
#  'BIRDE',
#  'Shozie',
# ...

# %%
#Previous page

previous=driver.find_element(By.CLASS_NAME,"ge-49M")
previous.click()

# %%
#Scrapping product desription from flipkart page

product_description=[]

description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:10]:
    description=i.text
    product_description.append(description)

# %%
#Scrap three page data

start=0
end=3
for page in range (start,end):
    description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description_tags:
        product_description.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
#Fetch top 100 data from product description

product_description[0:100]
# Out:
# ['Sneakers For Women',
#  'Combo Pack of 2 Casual Shoe Sneakers For Men',
#  'Combo Pack Of 2 Casual Shoes Sneakers For Men',
#  'Premium Sports Shoes For Men Pack Of 2 Sneakers For Men',
#  'Casuals, Canvas, Partywear Sneakers For Men',
#  'Combo Pack of 2 Casual Shoes Sneakers For Men',
#  'Synthetic Leather |Lightweight|Comfort|Summer|Trendy|Wa...',
#  'Stylish Sneakers Shoes for Women And Girls Sneakers For...',
#  "Men's W-05 Casual White Sneaker Shoes With Waterproof S...",
#  'Lattest Sneakers Shoe Sneakers For Men',
#  'Sneakers For Women',
#  'Combo Pack of 2 Casual Shoe Sneakers For Men',
#  'Combo Pack Of 2 Casual Shoes Sneakers For Men',
#  'Premium Sports Shoes For Men Pack Of 2 Sneakers For Men',
#  'Casuals, Canvas, Partywear Sneakers For Men',
#  'Combo Pack of 2 Casual Shoes Sneakers For Men',
#  'Synthetic Leather |Lightweight|Comfort|Summer|Trendy|Wa...',
#  'Stylish Sneakers Shoes for Women And Girls Sneakers For...',
# ...

# %%
#Previous page

previous=driver.find_element(By.CLASS_NAME,"ge-49M")
previous.click()

# %%
#Scrapping sunglasses price from flipkart page

price_list=[]

price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:10]:
    price=i.text
    price_list.append(price)

# %%
#Scrap three page data

start=0
end=3
for page in range (start,end):
    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        price_list.append(i.text)
    
    next_btn=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_btn.click()
    time.sleep(5)

# %%
#Fetch top 100 data from product price

price_list[0:100]
# Out:
# ['₹299',
#  '₹499',
#  '₹499',
#  '₹499',
#  '₹449',
#  '₹499',
#  '₹299',
#  '₹422',
#  '₹599',
#  '₹249',
#  '₹299',
#  '₹499',
#  '₹499',
#  '₹499',
#  '₹449',
#  '₹499',
#  '₹299',
#  '₹422',
#  '₹599',
#  '₹249',
#  '₹449',
#  '₹399',
#  '₹249',
#  '₹379',
#  '₹499',
#  '₹299',
#  '₹199',
#  '₹774',
#  '₹229',
#  '₹1,100',
#  '₹457',
#  '₹499',
#  '₹349',
#  '₹349',
#  '₹399',
#  '₹1,209',
#  '₹429',
#  '₹399',
#  '₹499',
#  '₹499',
#  '₹279',
#  '₹498',
#  '₹422',
#  '₹597',
#  '₹399',
#  '₹399',
#  '₹299',
#  '₹499',
#  '₹499',
#  '₹299',
#  '₹1,564',
#  '₹379',
#  '₹349',
#  '₹649',
#  '₹464',
#  '₹299',
#  '₹449',
#  '₹499',
#  '₹349',
#  '₹399',
#  '₹1,275',
#  '₹1,699',
#  '₹499',
#  '₹499',
#  '₹559',
#  '₹1,290',
#  '₹349',
#  '₹299',
#  '₹429',
#  '₹299',
#  '₹349',
#  '₹349',
#  '₹299',
#  '₹474',
#  '₹299',
#  '₹979',
#  '₹1,666',
#  '₹584',
#  '₹509',
#  '₹399',
#  '₹639',
#  '₹599',
#  '₹295',
#  '₹349',
#  '₹429',
#  '₹292',
#  '₹299',
#  '₹399',
#  '₹299',
# ...

# %%
#Print length

print(len(brand_name),len(product_description),len(price_list))
# Out:
# 130 127 130

# %%
#Create DataFrame

Sneakers=pd.DataFrame()
Sneakers["BRAND"]=brand_name[:100]
Sneakers["PRODUCT_DESCRIPTION"]=product_description[:100]
Sneakers["PRICE"]=price_list[:100]

Sneakers
# Out:
#      BRAND                                PRODUCT_DESCRIPTION PRICE
# 0   Kraasa                                 Sneakers For Women  ₹299
# 1    BIRDE       Combo Pack of 2 Casual Shoe Sneakers For Men  ₹499
# 2    BIRDE      Combo Pack Of 2 Casual Shoes Sneakers For Men  ₹499
# 3    BIRDE  Premium Sports Shoes For Men Pack Of 2 Sneaker...  ₹499
# 4   Kraasa        Casuals, Canvas, Partywear Sneakers For Men  ₹449
# ..     ...                                                ...   ...
# 95   BIRDE  Stylish Sneakers Shoes for Women And Girls Sne...  ₹499
# 96    aadi  Men's W-05 Casual White Sneaker Shoes With Wat...  ₹299
# 97  Shozie             Lattest Sneakers Shoe Sneakers For Men  ₹422
# 98   asian  Casual Sneakers White Shoes For Girls And Snea...  ₹599
# 99  BRUTON  Modern Trendy Sneakers boot Sneakers Sneakers ...  ₹249
#
# [100 rows x 3 columns]

# %% [markdown]
# <a id="amazon"> </a>
# ## 7. Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7”.
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
#Let's first connect to the driver

driver=webdriver.Chrome(r"C:\Users\HP\Internship\chromedriver_win32\chromedriver")

# %%
#Opening the amazon page on automated chrome browser

driver.get('https://www.amazon.in/')

# %%
#Entering product as required in the question

search_items=driver.find_element(By.XPATH,'//input[@class="nav-input nav-progressive-attribute"]')
search_items.send_keys("Laptop")

# %%
#Search

search=driver.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]')
search.click()

# %%
#Using CPU filter data ( Intel Core i7 )

CPU_filter=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[7]/span[9]/li/span/a/span")
CPU_filter.click()

# %%
#Scrapping product title from amazon page

Title=[]

laptop_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in laptop_tags[0:10]:
    laptop=i.text
    Title.append(laptop)

# %%
#Scrapping product ratings from amazon page

Ratings=[]

laptop_ratings=driver.find_elements(By.XPATH,'//span[@class="a-icon-alt"]')
for i in laptop_ratings[0:10]:
    rating=i.text
    Ratings.append(rating)

# %%
#Scrapping product price from amazon page

Price=[]

laptop_price=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in laptop_price[0:10]:
    price=i.text
    Price.append(price)

# %%
#Print length

print(len(Title),len(Ratings),len(Price))
# Out:
# 10 10 10

# %%
#Create DataFrame
import pandas as pd
Laptop=pd.DataFrame({'TITLE':Title,'RATINGS':Ratings,'PRICE':Price})
Laptop
# Out:
#                                                TITLE RATINGS     PRICE
# 0  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...            94,989
# 1  Acer Predator Helios Neo 16 Gaming Laptop 13th...          1,29,990
# 2  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...            98,990
# 3  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...            88,990
# 4  ASUS Zenbook Pro 14 Duo OLED (2022) Dual Scree...          1,24,990
# 5  Samsung Galaxy Book2 (NP750) Intel 12th Gen co...            79,990
# 6  HP Envy x360 12th Gen Intel Core i7-13.3 inch(...          1,02,990
# 7  HP Victus Gaming Latest 12th Gen Intel Core i7...            79,990
# 8  MSI Modern 14, Intel 13th Gen. i7-1355U, 36CM ...            74,990
# 9  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...            82,990

# %% [markdown]
# <a id="python_program"> </a>
# ## 8.Write a python program to scrape data for Top 1000 Quotes of All Time. The above task will be done in following steps:
# 1. First get the webpagehttps://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
#Install libraries
# !pip install bs4
# !pip install requests

# %%
#import libraries
from bs4 import BeautifulSoup
import requests

# %%
#display all the Quotes from azquotes

quotes=requests.get("https://www.azquotes.com/")
quotes
# Out:
# <Response [200]>

# %%
#Content

soup=BeautifulSoup(quotes.content)
soup
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <title>A-Z Quotes | Quotes for All Occasions</title>
# <meta content="Discover inspirational quotes, collect and share famous and rare quotes. Create beautiful and unique picture quotes in one click.
# Sayings from famous authors, movies and people." name="description"/>
# <meta content="1261243095" property="fb:admins"/>
# <meta content="A-Z Quotes" property="og:site_name"/>
# <meta content="A-Z Quotes | Quotes for All Occasions" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.azquotes.com" property="og:url"/>
# <meta content="Discover inspirational quotes, collect and share famous and rare quotes. Create beautiful and unique picture quotes in one click.
# Sayings from famous authors, movies and people." property="og:description"/>
# <meta content="summary" property="twitter:card"/>
# ...

# %%
#Scrap first quote

first_quote=soup.find('a',class_='title')
first_quote

first_quote.text
# Out:
# 'Doing what you love is the cornerstone of having abundance in your life.'

# %%
#Scrap all quotes

all_quotes=[]

for i in soup.find_all('a',class_='title'):
    all_quotes.append(i.text)
    
all_quotes
# Out:
# ['Doing what you love is the cornerstone of having abundance in your life.',
#  'A person who never made a mistake never tried anything new.',
#  'It takes less time to do a thing right, than it does to explain why you did it wrong.',
#  'Never give up, for that is just the place and time that the tide will turn.',
#  'If you follow the will of God, you know that in spite of all the terrible things that happen to you, you will never lose a final refuge. You know that the foundation of the world is love, so that even when no human being can or will help you, you may go on, trusting in the One that loves you.',
#  'A loving person lives in a loving world. A hostile person lives in a hostile world.',
#  'You have two choices: You can make a living, or you can design a life.',
#  'Evil is powerless if the good are unafraid.',
#  'Sharing makes you bigger than you are. The more you pour out, the more life will be able to pour in.',
# ...

# %%
#Scrap first author

author=soup.find('div',class_='author')
author

author.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [141], in <cell line: 6>()
#       3 author=soup.find('div',class_='author')
#       4 author
# ----> 6 author.text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# <a id="jagranjosh"> </a>
# ## 9. Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame.

# %%
#Let's first connect to the driver

driver=webdriver.Chrome(r"C:\Users\HP\Internship\chromedriver_win32\chromedriver")

# %%
#Opening the jagranjosh page on automated chrome browser

driver.get('https://www.jagranjosh.com/')

# %%
#Click on gk 

GK=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[3]/a")
GK.click()

# %%
#Click List of all Prime Ministers of India

PM_list=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
PM_list.click()

# %%
#Scrapping pm's name from azquotes page

PM_name=[]

name_tags=driver.find_elements(By.XPATH,'')
for i in name_tags[0:10]:
    name=i.text
    PM_name.append(name)
